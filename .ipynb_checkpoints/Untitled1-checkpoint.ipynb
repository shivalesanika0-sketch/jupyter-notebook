# %%
i = 20

while i >= 10:
    print(i)
    i -= 1
# Out:
# 20
# 19
# 18
# 17
# 16
# 15
# 14
# 13
# 12
# 11
# 10

# %%
start = int(input("Enter a number: "))

while start >= 1:
    print(start)
    start -= 1
# Out:
# Enter a number:  1
# 1

# %%
i = 10

while i >= 2:
    print(i)
    i -= 2
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
a="hello"
b="world"
print(a+b)
# Out:
# helloworld

# %%
text ="python"

print(text.upper())
print(text.lower())
print(len(text))
# Out:
# PYTHON
# python
# 6

# %%
marks = [80,90,75,60]
print(marks[0])
# Out:
# 80
