# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,15,30]

plt.plot(x,y)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = [10, 20, 20, 30, 30, 30, 40, 50]

# Create histogram
sns.histplot(data)

# Show plot
plt.show()
